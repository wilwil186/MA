# %% [markdown]
# <a href="https://colab.research.google.com/github/wilwil186/Machine-Learning-con-Python/blob/main/Curso_de_Clustering_con_Python_y_scikit_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ¿Qué es el clustering en machine learning?

# %% [markdown]
# El machine learning es un campo de la inteligencia artificial que se divide en tres grandes ramas: el aprendizaje supervisado, el no supervisado y el aprendizaje por refuerzo. En esta ocasión, nos centraremos en los dos primeros.
#
# La principal diferencia entre el aprendizaje supervisado y el no supervisado radica en que en el primero se cuenta con una variable objetivo, mientras que en el segundo no. Es decir, en el aprendizaje supervisado se tiene una idea previa de lo que se busca obtener, mientras que en el no supervisado se trata de encontrar patrones o estructuras ocultas en los datos.
#
# Dentro del aprendizaje no supervisado, encontramos el clustering, que consiste en agrupar datos similares en conjuntos o clusters. De esta forma, podemos obtener una mejor comprensión de los datos y utilizar esta información para tomar decisiones más informadas.

# %% [markdown]
# Clustering es un método muy útil en el análisis de datos, ya que puede ayudar a identificar patrones en grandes conjuntos de datos que serían difíciles de identificar de otra manera. Al agrupar los datos en clusters, podemos identificar las características comunes que comparten los elementos de cada grupo y obtener una mejor comprensión de los datos en general.
#
# El clustering se utiliza en muchos campos, como la biología, la astronomía, la informática, la psicología, entre otros. Por ejemplo, en biología se puede utilizar el clustering para agrupar células según su función o estructura, y en astronomía se puede utilizar para clasificar galaxias según su forma y tamaño.
#
# Existen varios algoritmos de clustering, como k-means, clustering jerárquico, clustering espectral, entre otros. Cada uno de ellos tiene sus propias ventajas y desventajas, y se debe elegir el que mejor se adapte a los datos que se estén analizando.
#
# En resumen, el clustering es una técnica muy útil en el análisis de datos no supervisado que nos permite identificar patrones y agrupar datos en clusters con características similares. Es una herramienta esencial en la exploración de datos y puede ayudar a descubrir información valiosa que de otra manera sería difícil de encontrar.

# %% [markdown]
# Además de los algoritmos de clustering que mencioné anteriormente, existen otras técnicas que se utilizan para agrupar datos no supervisados, como la reducción de dimensionalidad y la detección de anomalías.
#
# La reducción de dimensionalidad consiste en reducir la cantidad de variables o características que se tienen en un conjunto de datos sin perder información significativa. Por ejemplo, se puede utilizar la técnica de análisis de componentes principales (PCA) para reducir la dimensionalidad de un conjunto de datos y luego aplicar el clustering en el nuevo conjunto de datos reducido.
#
# La detección de anomalías, por otro lado, consiste en identificar elementos en un conjunto de datos que no se ajustan a los patrones normales o esperados. Esta técnica puede ser útil para identificar errores o fraudes en los datos, o para identificar eventos inusuales que pueden ser de interés.
#
# En cuanto a las aplicaciones prácticas del clustering, se utiliza en una variedad de campos, como el marketing, la segmentación de clientes, la clasificación de textos, la detección de spam, la identificación de genes, entre otros. Por ejemplo, en el marketing, el clustering se utiliza para segmentar a los clientes en diferentes grupos de acuerdo a sus características y comportamientos de compra, lo que permite a las empresas personalizar su oferta y mejorar su rentabilidad.
#
# En conclusión, el clustering es una técnica muy útil en el análisis de datos no supervisado que se utiliza para identificar patrones y agrupar datos en clusters con características similares. Se utiliza en una variedad de campos y tiene muchas aplicaciones prácticas en el mundo real.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Creamos un conjunto de datos aleatorio
X = np.random.rand(50, 2)

# Aplicamos k-means con 3 clusters
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)

# Obtenemos los centroides y las etiquetas de los clusters
centroids = kmeans.cluster_centers_
labels = kmeans.labels_

# Creamos un plot de dispersión de los datos y los clusters
colors = ["r.", "g.", "b."]
for i in range(len(X)):
    plt.plot(X[i][0], X[i][1], colors[labels[i]], markersize=10)
plt.scatter(centroids[:, 0], centroids[:, 1], marker="x", s=200, linewidths=3, color="black")
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# # Tu primer clustering con scikit-learn

# %% [markdown]
# ## Importar las librerias necesarias y carga de datos

# %%
from sklearn.datasets import make_blobs
import pandas as pd
import matplotlib.pyplot as plt

# %%
x, y = make_blobs(n_samples=100, centers=4, n_features=2, cluster_std=[1,1.5,2,2], random_state=7) 
# 100 datapoints, 4 centros, numero de features, cluster_sts desviación estantar, random_state para poder replicar los resultados

# %%
df_blobls = pd.DataFrame({
    'x1': x[:,0],
    'x2':x[:,1], 
    'y':y

})

# %%
df_blobls
# Out:
#            x1        x2  y
# 0   -3.384261  5.221740  1
# 1   -1.836238 -7.735384  3
# 2   -7.456176  6.198874  0
# 3   -1.785043  1.609749  1
# 4  -10.124910  6.133805  0
# ..        ...       ... ..
# 95   7.072755 -0.259937  2
# 96  -2.626873 -7.228570  3
# 97  -1.521099  1.802284  1
# 98  -9.216388  6.670846  0
# 99  -1.681382  6.414631  1
#
# [100 rows x 3 columns]

# %%
def plot_2d_clusters(x,y,ax):
    y_uniques = pd.Series(y).unique()

    for _ in y_uniques:
        x[y==_].plot(
            title=f'{len(y_uniques)} Clusters',
            kind='scatter',
            x='x1',
            y='x2',
            marker = f'${_}$',
            ax = ax
        )

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))
x, y = df_blobls[['x1','x2']], df_blobls['y']
plot_2d_clusters(x,y,ax)
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ## Aplicando clustering

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, random_state=7)
y_pred = kmeans.fit_predict(x)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
fig, axs = plt.subplots(1,2, figsize=(20,12))
plot_2d_clusters(x,y,axs[0])
plot_2d_clusters(x,y_pred,axs[1])

axs[0].set_title(f'Actual {axs[0].get_title()}')
axs[1].set_title(f'Kmeans {axs[1].get_title()}')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Text(0.5, 1.0, 'Kmeans 5 Clusters')

# %% [markdown]
# # ¿Cuándo usar clustering?
#
# El clustering es una técnica de aprendizaje no supervisado que se utiliza para encontrar patrones y estructuras en los datos. Se puede utilizar en diversas situaciones y contextos donde se desea identificar grupos o categorías naturales en los datos sin tener una variable objetivo predefinida.
#
# A continuación, se describen algunos casos en los que se puede utilizar clustering:
#
# - Mayor contexto de mi datasets: El clustering puede ayudar a descubrir patrones y estructuras en los datos que no son evidentes a simple vista. Esto puede proporcionar una mejor comprensión del conjunto de datos y puede ayudar a identificar relaciones y tendencias entre las variables.
#
# - Detección de outliers: El clustering también puede utilizarse para detectar outliers o valores atípicos en los datos que no siguen el patrón de los demás valores. Esto puede ser útil para identificar problemas o errores en los datos o para identificar posibles anomalías o excepciones en los datos.
#
# - Clasificar/Agrupar (sin variable objetivo): El clustering se utiliza comúnmente para clasificar y agrupar datos en categorías o grupos basados en características similares. Esto puede ser útil para identificar patrones en los datos y para simplificar la visualización y el análisis de grandes conjuntos de datos.
#
# - Tareas manuales de crear etiquetas: En algunos casos, es posible que no haya una variable objetivo clara o definida en los datos. En este caso, el clustering puede ser utilizado para agrupar los datos en categorías o grupos que pueden ser etiquetados manualmente para su posterior análisis.
#
# En cuanto a lo que se puede lograr con el clustering, aquí hay algunos ejemplos:
#
# - Clasificar el tráfico en una página: El clustering puede utilizarse para identificar patrones en el tráfico de una página web y clasificar a los visitantes en diferentes categorías, como nuevos visitantes, visitantes frecuentes, visitantes que compran con frecuencia, etc.
#
# - Segmentación de perfiles de clientes: El clustering puede ayudar a identificar patrones en los datos de los clientes y segmentarlos en diferentes grupos basados en características similares, como edad, género, ubicación, historial de compras, etc.
#
# - Clasificación de contenido: El clustering puede utilizarse para clasificar contenido en diferentes categorías, como noticias, entretenimiento, deportes, etc.
#
# - Identificar comportamientos fraudulentos: El clustering puede ser utilizado para identificar patrones en los datos que pueden indicar comportamientos fraudulentos o sospechosos, como transacciones inusuales o actividades sospechosas.
#
# - Ciencia en los deportes: El clustering puede ser utilizado en el análisis de datos en la ciencia en los deportes para identificar patrones en los datos relacionados con el rendimiento de los atletas, la eficacia de las tácticas de juego, etc.
#
# - Ciencia en los deportes: El clustering también puede ser utilizado en la ciencia en los deportes para segmentar a los fanáticos en diferentes grupos basados en su comportamiento, preferencias, etc.
#
# - Muchas posibilidades: El clustering puede ser utilizado en una amplia variedad de situaciones y contextos, desde el análisis de datos empresariales hasta la exploración de datos en la investigación científica y médica.

# %% [markdown]
# ## Clustering vs clasificación
# Tanto la clasificación como el clustering son técnicas de aprendizaje automático que se utilizan para analizar datos y encontrar patrones, pero existen diferencias clave entre ellas.
#
# La clasificación es una técnica supervisada que se utiliza para etiquetar o clasificar los datos en categorías predefinidas. En la clasificación, se utiliza un conjunto de datos de entrenamiento etiquetado para entrenar un modelo que luego se utiliza para predecir la categoría de nuevos datos no etiquetados. La clasificación se basa en la idea de que los datos tienen una variable objetivo conocida, es decir, la categoría o etiqueta a la que pertenece cada dato.
#
# Por otro lado, el clustering es una técnica no supervisada que se utiliza para agrupar los datos en categorías o grupos naturales basados en las similitudes entre ellos. En el clustering, no hay variable objetivo predefinida y los datos se agrupan en función de su similitud, sin conocer la categoría o etiqueta a la que pertenecen. El objetivo del clustering es encontrar patrones y estructuras ocultas en los datos que puedan proporcionar información útil sobre el conjunto de datos.
#
# En resumen, la principal diferencia entre la clasificación y el clustering es que la clasificación se utiliza para predecir la categoría de nuevos datos en función de un conjunto de datos de entrenamiento etiquetado, mientras que el clustering se utiliza para agrupar los datos en categorías naturales basados en las similitudes entre ellos, sin tener una variable objetivo predefinida.

# %% [markdown]
# # ¿Cómo evalaur modelos de clustering?

# %% [markdown]
# ## Coeficiente de silueta
#
# $s(i)=\frac{b-a}{max(a,b)}$
#
# - *a* es el promedio de las disimilitudes (o distancias) de la observación i con las demás observaciones del cluster al que pertenece i.
# - *b* es la distancia mínima a otro cluster que no es el mismo en el que está la observación i.
#
# Ese cluster es la segunda mejor opción para i y se lo denomina vecindad de i.

# %% [markdown]
# ![Captura de pantalla 2023-03-01 093033.png](data:image/png;base64,...)

# %% [markdown]
# # ¡Qué es el algortimo de k-means y cómo funciona?

# %% [markdown]
# ## k-means
# 1. Indicar cantidad de clusters.
# 2. Ubicar centroides aleatoriamente.
# 3. cada punto se asigna al centroide más cercano.
# 4. recalcular centroidescon el promedio.
# 5. Repatir paso 3 y 4 hasta que no se muevan los centroides.

# %% [markdown]
# ![Captura de pantalla 2023-03-01 101313.png](data:image/png;base64,...)

# %% [markdown]
# # Encontrando K

# %% [markdown]
# ## Método del Codo (Elbow)

# %% [markdown]
# Graficar la inercia o la suma de los errores cuadraticos

# %% [markdown]
# ![Captura desde 2023-03-05 08-06-01.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura desde 2023-03-05 08-06-53.png](data:image/png;base64,...)

# %% [markdown]
# # ¿Cuándo usar hirarchical clustering?

# %% [markdown]
# El clustering jerárquico o hierarchical clustering es una técnica de agrupamiento que se utiliza para clasificar objetos en función de su similitud. Se puede utilizar en diferentes situaciones, como:
#
# 1. Análisis de datos exploratorios: El clustering jerárquico puede ayudar a identificar patrones en los datos y a explorar la estructura de los mismos.
#
# 2. Segmentación de mercado: En el análisis de mercado, se puede utilizar el clustering jerárquico para identificar grupos de consumidores con características similares, lo que permite a las empresas adaptar su oferta a los diferentes segmentos.
#
# 3. Análisis de imagen: En la visión por computadora, el clustering jerárquico puede utilizarse para segmentar imágenes y encontrar patrones en ellas.
#
# 4. Análisis de secuencias: El clustering jerárquico también se puede aplicar en el análisis de secuencias, como en la identificación de grupos de genes con expresión similar en un conjunto de datos de microarrays.
#
# En resumen, el clustering jerárquico es útil cuando se necesita clasificar objetos en función de su similitud y cuando se quiere explorar la estructura de los datos sin tener una idea clara de cuántos grupos existen. Además, es una técnica útil cuando se desea obtener una clasificación en diferentes niveles de granularidad.

# %% [markdown]
# # Implementando hirechical clustering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
X,y, c = make_blobs(500, cluster_std=0.8, centers=4, n_features=2,return_centers=True)

df_blobs = pd.DataFrame(
    {
        'x1': X[:,0],
        'x2': X[:,1],
        'y': y,
    }
)

df_centers = pd.DataFrame(
    {
        'x1': c[:,0],
        'x2': c[:,1],
    }
)

# %%
df_blobs
# Out:
#            x1        x2  y
# 0   -8.214599  5.350702  1
# 1    1.059541 -2.126541  3
# 2   -7.458528  5.868918  1
# 3   -0.848765  0.202439  0
# 4    0.876403 -3.959701  3
# ..        ...       ... ..
# 495 -3.051533 -5.390820  2
# 496  1.295408 -1.698833  0
# 497  3.799695 -0.871464  3
# 498  1.001216 -1.290170  3
# 499  0.320602 -3.650315  3
#
# [500 rows x 3 columns]

# %%
fig = plt.figure(figsize=(8,8))
sns.scatterplot(data=df_blobs, x='x1',y='x2')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
dendrogram_plot = dendrogram(linkage(X, method='ward'))
plt.title('Dendrograma usando ward linkage')
plt.xlabel('Cluster', fontsize=12)
plt.ylabel('Distancia Euclidiana')
plt.show()

# %%
hc = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')
y_hc = hc.fit_predict(X)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
df_blobs['cluster'] = y_hc

# %%
fig = plt.figure(figsize=(8,8))
sns.scatterplot(data=df_blobs, x='x1',y='x2', hue='cluster', palette='coolwarm')
plt.show()

# %% [markdown]
# # Evaluando resultados de hirearchical clustering

# %%
silhouette_score(X,y_hc)
# Out:
# 0.6087814948346925

# %% [markdown]
# ## ¿Qué es DBSCAN y cómo funciona?
#
# - Clustering badaso en densidad
# - Su principio se basa en que un cluster tiene alta densidad, mientras que la región quye los epara no la tiene.
#
# - La idea principal es que cada punto en el cluster de acuerdo a un radio dado debe tener un minimo de vecinos o puntos cercanos oara encontrar densidad.
# - Requiere dos parámetros:
#   - Eps (epsilon)
#   - minPts (mínimos de puntos)

# %% [markdown]
# # Aplicando PCA para clustering

# %% [markdown]
# ## preparar datos
#
# - Eliminar duplicados
# - Remover colunmas innecesarias.
# - Remover outliers.
# - Escalar data.
# - **Reducción de dimensionalidad**
